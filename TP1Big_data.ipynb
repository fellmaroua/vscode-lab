# %% [markdown]
# <a href="https://colab.research.google.com/github/fellmaroua/vscode-lab/blob/main/TP1Big_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd
import time

api_key = "2d0e8e54"
base_url = "http://www.omdbapi.com/"

all_movies = []

keywords = ["love", "war", "life", "night", "day", "death", "star", "man", "woman", "king"]

for keyword in keywords:
    for page in range(1, 101):
        params = {"apikey": api_key, "s": keyword, "type": "movie", "page": page}
        response = requests.get(base_url, params=params)
        data = response.json()

        if data.get("Search"):
            for movie in data["Search"]:
                all_movies.append({
                    "Title": movie.get("Title"),
                    "Year": movie.get("Year"),
                    "imdbID": movie.get("imdbID"),
                    "Type": movie.get("Type"),
                    "Poster": movie.get("Poster")
                })
        else:
            break
        time.sleep(0.2)

df = pd.DataFrame(all_movies)
df.to_csv("movies_1000.csv", index=False, encoding="utf-8")
print(f" تم حفظ {len(df)} فيلم في الملف movies_1000.csv")
